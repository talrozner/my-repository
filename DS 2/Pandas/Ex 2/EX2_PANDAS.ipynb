# %%
#import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %config IPCompleter.greedy=True #autocomplete jupyter

# %%
#load the file
file_path = r'DatafinitiElectronicsProductsPricingData.csv'
data = pd.read_csv(file_path)

#data info()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14592 entries, 0 to 14591
# Data columns (total 31 columns):
# id                     14592 non-null object
# prices.amountMax       14592 non-null float64
# prices.amountMin       14592 non-null float64
# prices.availability    12667 non-null object
# prices.condition       13189 non-null object
# prices.currency        14592 non-null object
# prices.dateSeen        14592 non-null object
# prices.isSale          14592 non-null bool
# prices.merchant        13820 non-null object
# prices.shipping        8793 non-null object
# prices.sourceURLs      14592 non-null object
# asins                  14592 non-null object
# brand                  14592 non-null object
# categories             14592 non-null object
# dateAdded              14592 non-null object
# dateUpdated            14592 non-null object
# ean                    4208 non-null object
# imageURLs              14592 non-null object
# keys                   14592 non-null object
# manufacturer           7618 non-null object
# manufacturerNumber     14592 non-null object
# name                   14592 non-null object
# primaryCategories      14592 non-null object
# sourceURLs             14592 non-null object
# upc                    14592 non-null object
# weight                 14592 non-null object
# Unnamed: 26            39 non-null object
# Unnamed: 27            18 non-null object
# Unnamed: 28            6 non-null float64
# Unnamed: 29            12 non-null object
# Unnamed: 30            6 non-null object
# dtypes: bool(1), float64(3), object(27)
# memory usage: 3.4+ MB

# %%
data.head()
# Out:
#                      id  prices.amountMax  prices.amountMin  \
# 0  AVphzgbJLJeJML43fA0o            104.99            104.99
# 1  AVpgMuGwLJeJML43KY_c             69.00             64.99
# 2  AVpgMuGwLJeJML43KY_c             69.00             69.00
# 3  AVpgMuGwLJeJML43KY_c             69.99             69.99
# 4  AVpgMuGwLJeJML43KY_c             66.99             66.99
#
#   prices.availability prices.condition prices.currency  \
# 0                 Yes              New             USD
# 1            In Stock              New             USD
# 2            In Stock              New             USD
# 3                 Yes              New             USD
# 4                 Yes              New             USD
#
#                                      prices.dateSeen  prices.isSale  \
# 0  2017-03-30T06:00:00Z,2017-03-10T22:00:00Z,2017...          False
# 1                               2017-12-14T06:00:00Z           True
# 2                               2017-09-08T05:00:00Z          False
# 3                               2017-10-10T05:00:00Z          False
# 4                               2017-08-28T07:00:00Z          False
#
#   prices.merchant prices.shipping     ...      \
# 0     Bestbuy.com             NaN     ...
# 1     Walmart.com       Expedited     ...
# 2     Walmart.com       Expedited     ...
# 3     Bestbuy.com             NaN     ...
# 4     Bestbuy.com             NaN     ...
#
#                                                 name primaryCategories  \
# 0  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...       Electronics
# 1  Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 2  Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 3  Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 4  Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
#
#                                           sourceURLs          upc  \
# 0  https://www.amazon.com/Sanus-VLF410B1-10-Inch-...  7.93796E+11
# 1  http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 2  http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 3  http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 4  http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
#
#         weight Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30
# 0  32.8 pounds         NaN         NaN         NaN         NaN         NaN
# 1    14 pounds         NaN         NaN         NaN         NaN         NaN
# 2    14 pounds         NaN         NaN         NaN         NaN         NaN
# 3    14 pounds         NaN         NaN         NaN         NaN         NaN
# 4    14 pounds         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 31 columns]
